# %%
df = spark.read.table("databricks_dinesh.silver.sales_enr")

# %%
df.display()

# %%
# %sql
CREATE TABLE databricks_dinesh.bronze.scd1_source(
  product_id INT,
  product_name STRING,
  load_time TIMESTAMP
)

# %%
# %sql
INSERT INTO databricks_dinesh.bronze.scd1_source VALUES
(1, 'Honey', current_timestamp()),
(2, 'Jam', current_timestamp()),
(3, 'Marmalade', current_timestamp()),
(4, 'Chocolate', current_timestamp()),
(5, 'Coffee', current_timestamp()),
(6, 'Milk Tea', current_timestamp()),
(7, 'Roast', current_timestamp())
